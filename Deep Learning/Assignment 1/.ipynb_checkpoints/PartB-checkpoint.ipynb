# %% [markdown]
# # R00182510 - Assignment1 PART B

# %% [markdown]
# ### Task 1 - Keras

# %%
# To enable TF2
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0-rc2

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/My Drive/Colab Notebooks/data-1.zip"
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/data-1.zip
#   inflating: data.h5

# %%
# import required libraries
import numpy as np
import h5py

# load training and test data  
def loadData():
    with h5py.File('data.h5','r') as hf:
      print('List of arrays in this file: \n', hf.keys())
      allTrain = hf.get('trainData')
      allTest = hf.get('testData')
      npTrain = np.array(allTrain)
      npTest = np.array(allTest)
        

    return npTrain[:,:-1], npTrain[:, -1], npTest[:,:-1], npTest[:, -1]

trainX, trainY, testX, testY = loadData()

print('Shape of the feature training data: \n', trainX.shape)
print('Shape of the feature test data: \n', testX.shape)
print('Shape of the true training class labels: \n', trainY.shape)
print('Shape of the true test class labels: \n', testY.shape)
# Out:
# List of arrays in this file:
#  <KeysViewHDF5 ['testData', 'trainData']>
# Shape of the feature training data:
#  (200000, 784)
# Shape of the feature test data:
#  (17000, 784)
# Shape of the true training class labels:
#  (200000,)
# Shape of the true test class labels:
#  (17000,)

# %%
# import required libraries
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

NUM_EPOCHS = 10

# build a model with a softmax layer contaning 10 neurons
model1 = tf.keras.models.Sequential( [
  layers.Dense(10, activation=tf.nn.softmax, input_shape= (784,))
] )

model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model1.fit(trainX, trainY, batch_size = 256, epochs=NUM_EPOCHS, validation_data=(testX, testY))

# Plot the training and the validation accuracy and loss     
plt.style.use("ggplot")
plt.figure()
plt.axis([0, NUM_EPOCHS, 0, 1])
plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc='lower left')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.7367 - accuracy: 0.8051 - val_loss: 0.5746 - val_accuracy: 0.8518
# Epoch 2/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6498 - accuracy: 0.8286 - val_loss: 0.5621 - val_accuracy: 0.8536
# Epoch 3/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6387 - accuracy: 0.8313 - val_loss: 0.5564 - val_accuracy: 0.8549
# Epoch 4/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6333 - accuracy: 0.8327 - val_loss: 0.5550 - val_accuracy: 0.8552
# Epoch 5/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6303 - accuracy: 0.8332 - val_loss: 0.5522 - val_accuracy: 0.8540
# Epoch 6/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6277 - accuracy: 0.8339 - val_loss: 0.5514 - val_accuracy: 0.8562
# Epoch 7/10
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers

NUM_EPOCHS = 10

# build a model with 1 hidden layer and a softmax layer
model2 = tf.keras.models.Sequential( [
  layers.Dense(300, activation=tf.nn.relu, input_shape= (784,)),
  layers.Dense(10, activation=tf.nn.softmax)
] )

model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model2.fit(trainX, trainY, batch_size = 256, epochs=NUM_EPOCHS, validation_data=(testX, testY))

# Plot the training and the validation accuracy and loss     
plt.style.use("ggplot")
plt.figure()
plt.axis([0, NUM_EPOCHS, 0, 1])
plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc='lower left')


# results = model2.evaluate(testX, testY)

# print (results)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.5075 - accuracy: 0.8532 - val_loss: 0.3611 - val_accuracy: 0.8981
# Epoch 2/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.3909 - accuracy: 0.8856 - val_loss: 0.3185 - val_accuracy: 0.9091
# Epoch 3/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.3489 - accuracy: 0.8984 - val_loss: 0.3170 - val_accuracy: 0.9074
# Epoch 4/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.3222 - accuracy: 0.9055 - val_loss: 0.3057 - val_accuracy: 0.9127
# Epoch 5/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.3010 - accuracy: 0.9117 - val_loss: 0.3007 - val_accuracy: 0.9145
# Epoch 6/10
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2837 - accuracy: 0.9166 - val_loss: 0.2943 - val_accuracy: 0.9149
# Epoch 7/10
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

NUM_EPOCHS = 10

# build a model with 2 hidden layers and a softmax layer
model4 = tf.keras.models.Sequential( [
  layers.Dense(400, activation=tf.nn.relu, input_shape= (784,)),
  layers.Dense(200, activation=tf.nn.relu),
  layers.Dense(10, activation=tf.nn.softmax)
] )

model4.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model4.fit(trainX, trainY, batch_size = 256, epochs=NUM_EPOCHS, validation_data=(testX, testY))

# Plot the training and the validation accuracy and loss    
plt.style.use("ggplot")
plt.figure()
plt.axis([0, NUM_EPOCHS, 0, 1])
plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc='lower left')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 7s 9ms/step - loss: 0.4696 - accuracy: 0.8602 - val_loss: 0.3213 - val_accuracy: 0.9025
# Epoch 2/10
# 782/782 [==============================] - 6s 8ms/step - loss: 0.3476 - accuracy: 0.8945 - val_loss: 0.2900 - val_accuracy: 0.9117
# Epoch 3/10
# 782/782 [==============================] - 6s 8ms/step - loss: 0.3021 - accuracy: 0.9075 - val_loss: 0.2743 - val_accuracy: 0.9170
# Epoch 4/10
# 782/782 [==============================] - 7s 9ms/step - loss: 0.2704 - accuracy: 0.9164 - val_loss: 0.2658 - val_accuracy: 0.9227
# Epoch 5/10
# 782/782 [==============================] - 7s 8ms/step - loss: 0.2446 - accuracy: 0.9238 - val_loss: 0.2582 - val_accuracy: 0.9249
# Epoch 6/10
# 782/782 [==============================] - 7s 8ms/step - loss: 0.2230 - accuracy: 0.9305 - val_loss: 0.2670 - val_accuracy: 0.9232
# Epoch 7/10
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers

NUM_EPOCHS = 10

# build a model with 3 hidden layers and a softmax layer
model5 = tf.keras.models.Sequential( [
  layers.Dense(600, activation=tf.nn.relu, input_shape= (784,)),
  layers.Dense(400, activation=tf.nn.relu),
  layers.Dense(200, activation=tf.nn.relu),
  layers.Dense(10, activation=tf.nn.softmax)
] )

model5.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model5.fit(trainX, trainY, batch_size = 256, epochs=NUM_EPOCHS, validation_data=(testX, testY))

# Plot the training and the validation accuracy and loss    
plt.style.use("ggplot")
plt.figure()
plt.axis([0, NUM_EPOCHS, 0, 1])
plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc='lower left')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.4536 - accuracy: 0.8616 - val_loss: 0.3130 - val_accuracy: 0.9035
# Epoch 2/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.3337 - accuracy: 0.8966 - val_loss: 0.2706 - val_accuracy: 0.9159
# Epoch 3/10
# 782/782 [==============================] - 11s 15ms/step - loss: 0.2873 - accuracy: 0.9097 - val_loss: 0.2638 - val_accuracy: 0.9186
# Epoch 4/10
# 782/782 [==============================] - 11s 15ms/step - loss: 0.2536 - accuracy: 0.9187 - val_loss: 0.2620 - val_accuracy: 0.9218
# Epoch 5/10
# 782/782 [==============================] - 11s 15ms/step - loss: 0.2268 - accuracy: 0.9273 - val_loss: 0.2612 - val_accuracy: 0.9249
# Epoch 6/10
# 782/782 [==============================] - 12s 15ms/step - loss: 0.2025 - accuracy: 0.9351 - val_loss: 0.2599 - val_accuracy: 0.9266
# Epoch 7/10
# ...

# %% [markdown]
# ### Task 2 - Dropout Regularization

# %%
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

NUM_EPOCHS = 50

# build a model with 2 hidden layers with Dropouts and a softmax layer
model6 = tf.keras.models.Sequential( [
  layers.Dense(400, activation=tf.nn.relu, input_shape= (784,)),
  layers.Dropout(0.4),
  layers.Dense(200, activation=tf.nn.relu),
  layers.Dropout(0.2),
  layers.Dense(10, activation=tf.nn.softmax)
] )

model6.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model6.fit(trainX, trainY, batch_size = 256, epochs=NUM_EPOCHS, validation_data=(testX, testY))

# Plot the training and the validation accuracy and loss    
plt.style.use("ggplot")
plt.figure()
plt.axis([0, NUM_EPOCHS, 0, 1])
plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
# plt.text(10, 0.6, r'$Dropout\ probability=%.3f$' % (0.6))
plt.legend(loc='center right')

# results = model6.evaluate(testX, testY)

# print (results)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5661 - accuracy: 0.8302 - val_loss: 0.3628 - val_accuracy: 0.8919
# Epoch 2/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4513 - accuracy: 0.8620 - val_loss: 0.3298 - val_accuracy: 0.9016
# Epoch 3/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4165 - accuracy: 0.8719 - val_loss: 0.3043 - val_accuracy: 0.9084
# Epoch 4/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3960 - accuracy: 0.8782 - val_loss: 0.2955 - val_accuracy: 0.9099
# Epoch 5/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3797 - accuracy: 0.8827 - val_loss: 0.2830 - val_accuracy: 0.9121
# Epoch 6/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3686 - accuracy: 0.8853 - val_loss: 0.2789 - val_accuracy: 0.9146
# Epoch 7/50
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

NUM_EPOCHS = 50

# build a model with 3 hidden layers with Dropouts and a softmax layer
model7 = tf.keras.models.Sequential( [
  layers.Dense(600, activation=tf.nn.relu, input_shape= (784,)),
  layers.Dropout(0.4),
  layers.Dense(400, activation=tf.nn.relu),
  layers.Dropout(0.4),
  layers.Dense(200, activation=tf.nn.relu),
  layers.Dropout(0.4),
  layers.Dense(10, activation=tf.nn.softmax)
] )

model7.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model7.fit(trainX, trainY, batch_size = 256, epochs=NUM_EPOCHS, validation_data=(testX, testY))

# Plot the training and the validation accuracy and loss    
plt.style.use("ggplot")
plt.figure()
plt.axis([0, NUM_EPOCHS, 0, 1])
plt.plot(np.arange(0, NUM_EPOCHS), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, NUM_EPOCHS), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
# plt.text(10, 0.6, r'$Dropout\ probability=%.3f$' % (0.4))
plt.legend(loc='center right')


# results = model7.evaluate(testX, testY)

# print (results)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5858 - accuracy: 0.8245 - val_loss: 0.3557 - val_accuracy: 0.8895
# Epoch 2/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4629 - accuracy: 0.8597 - val_loss: 0.3250 - val_accuracy: 0.9034
# Epoch 3/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4251 - accuracy: 0.8701 - val_loss: 0.3024 - val_accuracy: 0.9067
# Epoch 4/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4015 - accuracy: 0.8777 - val_loss: 0.2894 - val_accuracy: 0.9124
# Epoch 5/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3856 - accuracy: 0.8822 - val_loss: 0.2838 - val_accuracy: 0.9134
# Epoch 6/50
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3740 - accuracy: 0.8856 - val_loss: 0.2737 - val_accuracy: 0.9184
# Epoch 7/50
# ...
